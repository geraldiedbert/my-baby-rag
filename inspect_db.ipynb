# %%
import chromadb
import pandas as pd

client = chromadb.PersistentClient(path="chroma_persistent_storage")
collection = client.get_collection("document_qa_collection")

# Get some rows from Chroma
result = collection.get(
    include=["documents", "embeddings", "metadatas"],
    limit=100,     # or however many you want to inspect
)

rows = []
for doc, emb, meta in zip(
    result["documents"],
    result["embeddings"],
    result["metadatas"],
):
    rows.append({
        "text": doc,
        "embedding_len": len(emb),
        "embedding_first5": emb[:5],
        "metadata": meta,
    })

df = pd.DataFrame(rows)

# %%
pd.set_option("display.max_rows", 1000)
df

# %%
import os
from google import genai
from google.genai import types
from chromadb.utils import embedding_functions

google_api_key = os.getenv("GOOGLE_API_KEY")

gemini_ef = embedding_functions.GoogleGenaiEmbeddingFunction(
    model_name="gemini-embedding-001"
)
gemini_client = genai.Client(api_key=google_api_key)
# You need your gemini_client and the same model as in ingest
resp = gemini_client.models.embed_content(
    model="gemini-embedding-001",
    contents=["tell me about sleep"],
)
query_embedding = resp.embeddings[0].values

answer = collection.query(query_embeddings=[query_embedding], n_results=2)

# chunked_docs = [doc for sublist in answer['documents'] for doc in sublist]
# chunked_docs
# Out:
# /Users/geraldiedbert/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz:   4%|▎         | 2.87M/79.3M [01:32<40:57, 32.6kiB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 answer = collection.query(query_texts="tell me about sleep", n_results=2)
#       2 answer
#       3 # chunked_docs = [doc for sublist in answer['documents'] for doc in sublist]
#       4 # chunked_docs
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/chromadb/api/models/Collection.py:241, in Collection.query(self, query_embeddings, query_texts, query_images, query_uris, ids, n_results, where, where_document, include)
#     182 def query(
#     183     self,
#     184     query_embeddings: Optional[
#    (...)    201     ],
#     202 ) -> QueryResult:
#     203     """Query for the K nearest neighbor records in the collection.
#     204
#     205     This is a batch query API. Multiple queries can be performed at once
#    (...)    238         ValueError: If multiple query input types are provided.
#     239     """
# --> 241     query_request = self._validate_and_prepare_query_request(
#     242         query_embeddings=query_embeddings,
#     243         query_texts=query_texts,
#     244         query_images=query_images,
#     245         query_uris=query_uris,
#     246         ids=ids,
#     247         n_results=n_results,
#     248         where=where,
#     249         where_document=where_document,
#     250         include=include,
#     251     )
#     253     query_results = self._client._query(
#     254         collection_id=self.id,
#     255         ids=query_request["ids"],
#    (...)    262         database=self.database,
#     263     )
#     265     return self._transform_query_response(
#     266         response=query_results, include=query_request["include"]
#     267     )
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/chromadb/api/models/CollectionCommon.py:103, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#     100 @functools.wraps(func)
#     101 def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#     102     try:
# --> 103         return func(self, *args, **kwargs)
#     104     except Exception as e:
#     105         msg = f"{str(e)} in {name}."
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/chromadb/api/models/CollectionCommon.py:336, in CollectionCommon._validate_and_prepare_query_request(self, query_embeddings, query_texts, query_images, query_uris, ids, n_results, where, where_document, include)
#     334 if query_records["embeddings"] is None:
#     335     validate_record_set_for_embedding(record_set=query_records)
# --> 336     request_embeddings = self._embed_record_set(
#     337         record_set=query_records, is_query=True
#     338     )
#     339 else:
#     340     request_embeddings = query_records["embeddings"]
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/chromadb/api/models/CollectionCommon.py:724, in CollectionCommon._embed_record_set(self, record_set, embeddable_fields, is_query)
#     719             return self._embed(
#     720                 input=self._data_loader(uris=cast(URIs, record_set[field])),  # type: ignore[literal-required]
#     721                 is_query=is_query,
#     722             )
#     723         else:
# --> 724             return self._embed(
#     725                 input=record_set[field],  # type: ignore[literal-required]
#     726                 is_query=is_query,
#     727             )
#     728 raise ValueError(
#     729     "Record does not contain any non-None fields that can be embedded."
#     730     f"Embeddable Fields: {embeddable_fields}"
#     731     f"Record Fields: {record_set}"
#     732 )
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/chromadb/api/models/CollectionCommon.py:746, in CollectionCommon._embed(self, input, is_query)
#     744 if config_ef is not None:
#     745     if is_query:
# --> 746         return config_ef.embed_query(input=input)
#     747     else:
#     748         return config_ef(input=input)
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/chromadb/api/types.py:851, in EmbeddingFunction.embed_query(self, input)
#     842 def embed_query(self, input: D) -> Embeddings:
#     843     """Embed a query input.
#     844
#     845     Use this to create embeddings for documents and embeddings for queries/searches differently.
#    (...)    849     If not overridden, this calls ``__call__``.
#     850     """
# --> 851     return self.__call__(input)
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/chromadb/api/types.py:859, in EmbeddingFunction.__init_subclass__.<locals>.__call__(self, input)
#     858 def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 859     result = call(self, input)
#     860     assert result is not None
#     861     return validate_embeddings(cast(Embeddings, normalize_embeddings(result)))
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/chromadb/api/types.py:959, in DefaultEmbeddingFunction.__call__(self, input)
#     953 def __call__(self, input: Documents) -> Embeddings:
#     954     # Import here to avoid circular imports
#     955     from chromadb.utils.embedding_functions.onnx_mini_lm_l6_v2 import (
#     956         ONNXMiniLM_L6_V2,
#     957     )
# --> 959     return ONNXMiniLM_L6_V2()(input)
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/chromadb/api/types.py:859, in EmbeddingFunction.__init_subclass__.<locals>.__call__(self, input)
#     858 def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 859     result = call(self, input)
#     860     assert result is not None
#     861     return validate_embeddings(cast(Embeddings, normalize_embeddings(result)))
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/chromadb/utils/embedding_functions/onnx_mini_lm_l6_v2.py:270, in ONNXMiniLM_L6_V2.__call__(self, input)
#     259 """
#     260 Generate embeddings for the given documents.
#     261
#    (...)    266     Embeddings for the documents.
#     267 """
#     269 # Only download the model when it is actually used
# --> 270 self._download_model_if_not_exists()
#     272 # Generate embeddings
#     273 embeddings = self._forward(input)
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/chromadb/utils/embedding_functions/onnx_mini_lm_l6_v2.py:308, in ONNXMiniLM_L6_V2._download_model_if_not_exists(self)
#     301 os.makedirs(self.DOWNLOAD_PATH, exist_ok=True)
#     302 if not os.path.exists(
#     303     os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME)
#     304 ) or not _verify_sha256(
#     305     os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME),
#     306     self._MODEL_SHA256,
#     307 ):
# --> 308     self._download(
#     309         url=self.MODEL_DOWNLOAD_URL,
#     310         fname=os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME),
#     311     )
#     312 with tarfile.open(
#     313     name=os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME),
#     314     mode="r:gz",
#     315 ) as tar:
#     316     if sys.version_info >= (3, 12):
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/tenacity/__init__.py:331, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     329 copy = self.copy()
#     330 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 331 return copy(f, *args, **kw)
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/tenacity/__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     391 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     392     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393         self._add_action_func(lambda rs: rs.outcome.result())
#     394         return
#     396     if self.after is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/chromadb/utils/embedding_functions/onnx_mini_lm_l6_v2.py:116, in ONNXMiniLM_L6_V2._download(self, url, fname, chunk_size)
#     108 total = int(resp.headers.get("content-length", 0))
#     109 with open(fname, "wb") as file, self.tqdm(
#     110     desc=str(fname),
#     111     total=total,
#    (...)    114     unit_divisor=1024,
#     115 ) as bar:
# --> 116     for data in resp.iter_bytes(chunk_size=chunk_size):
#     117         size = file.write(data)
#     118         bar.update(size)
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/httpx/_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/httpx/_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/httpx/_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/httpx/_transports/default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Documents/GitHub/my-baby-rag/venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
